# %% [markdown]
# Imports and other variables

# %% [markdown]
# Init dataframes

# %%
import pandas as pd
import numpy as np
import os
from sklearn.linear_model import SGDClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

df = pd.read_csv(r'data/data_processed.csv')
df_cat = pd.read_csv(r'data/data_categorical.csv')

df_good = pd.concat([df_cat, df["MonthlyIncome"], df["BusinessTravel"], df["StockOptionLevel"], df["DistanceFromHome"], df["Age"]], axis=1)

# print(df_good)
# copy attrition and drop from dataframe
JAtt = df["Attrition"].values

df_good = df_good.drop(["Unnamed: 0"], axis=1)
# df_good = df_good.drop(['Attrition'], axis=1)
# print(df_good)

# splitting new df
df_train = df_good.iloc[:1200,:]
df_val = df_good.iloc[1200:,:]
# splitting Jatt into new sizes
JAtt_train = JAtt[:1200]
JAtt_val = JAtt[1200:]

# %% [markdown]
# Random forest classifier

# %%
# Random Forests
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# categorical data classifier
clf = RandomForestClassifier(max_depth=None, random_state=None)

clf.fit(df_train, JAtt_train)
acc_clf = clf.score(df_val, JAtt_val)

pred = clf.predict(df_val)

print(classification_report(JAtt_val, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       221
#            1       1.00      1.00      1.00        49
#
#     accuracy                           1.00       270
#    macro avg       1.00      1.00      1.00       270
# weighted avg       1.00      1.00      1.00       270

# %% [markdown]
# Print results

# %%
# print results
print('Data accuracy: ', acc_clf)

# print(allColumnsNames)
# Out:
# Data accuracy:  1.0

# %% [markdown]
# Tensorflow

# %%
import numpy as np
import pandas as pd
import tensorflow as tf

from tensorflow.keras import layers

# split data into training, validation and test
train, val, test = np.split(df_good.sample(frac=1), [int(0.8*len(df_good)), int(0.9*len(df_good))])

print(len(train), 'training examples')
print(len(val), 'validation examples')
print(len(test), 'test examples')
# Out:
# 1176 training examples
# 147 validation examples
# 147 test examples

# %%
def df_to_dataset(dataframe, shuffle=True, batch_size=32):
  _df = dataframe.copy()
  target = _df.pop('Attrition')

  _df = {key: value[:,tf.newaxis] for key, value in dataframe.items()}
  ds = tf.data.Dataset.from_tensor_slices((dict(_df), target))
  if shuffle:
    ds = ds.shuffle(buffer_size=len(dataframe))
  ds = ds.batch(batch_size)
  ds = ds.prefetch(batch_size)
  return ds

ds_train = df_to_dataset(train, True, 5)

[(train_features, label_batch)] = ds_train.take(1)
print('Every feature:', list(train_features.keys()))
print('A batch of job JobSatisfaction:', train_features["JobSatisfaction"])
print('A batch of targets:', label_batch )
# Out:
# Every feature: ['Attrition', 'BusinessTravel', 'Education', 'EnvironmentSatisfaction', 'Gender', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MaritalStatus', 'NumCompaniesWorked', 'OverTime', 'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel', 'TrainingTimesLastYear', 'WorkLifeBalance', 'MonthlyIncome', 'DistanceFromHome', 'Age']
# A batch of job JobSatisfaction: tf.Tensor(
# [[3]
#  [4]
#  [3]
#  [2]
#  [2]], shape=(5, 1), dtype=int64)
# A batch of targets: tf.Tensor([0 0 0 0 0], shape=(5,), dtype=int64)
# C:\Users\siman\AppData\Local\Temp\ipykernel_936\548746522.py:5: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   _df = {key: value[:,tf.newaxis] for key, value in dataframe.items()}

# %%
def get_normalization_layer(name, dataset):
  # Create a Normalization layer for the feature.
  normalizer = layers.Normalization(axis=None)

  # Prepare a Dataset that only yields the feature.
  feature_ds = dataset.map(lambda x, y: x[name])

  # Learn the statistics of the data.
  normalizer.adapt(feature_ds)

  return normalizer

monthly_rate_col = df["MonthlyIncome"]
layer = get_normalization_layer('MonthlyIncome', ds_train)
layer(monthly_rate_col)
# Out:
# <tf.Tensor: shape=(1, 1470), dtype=float32, numpy=
# array([[ 0.8607821 , -0.28995445, -0.28260565, ..., -0.79896736,
#         -0.17021215, -0.7360702 ]], dtype=float32)>

# %%
def get_category_encoding_layer(name, dataset, dtype, max_tokens=None):
  # Create a layer that turns strings into integer indices.
  if dtype == 'string':
    index = layers.StringLookup(max_tokens=max_tokens)
  # Otherwise, create a layer that turns integer values into integer indices.
  else:
    index = layers.IntegerLookup(max_tokens=max_tokens)

  # Prepare a `tf.data.Dataset` that only yields the feature.
  feature_ds = dataset.map(lambda x, y: x[name])

  # Learn the set of possible values and assign them a fixed integer index.
  index.adapt(feature_ds)

  # Encode the integer indices.
  encoder = layers.CategoryEncoding(num_tokens=index.vocabulary_size())

  # Apply multi-hot encoding to the indices. The lambda function captures the
  # layer, so you can use them, or include them in the Keras Functional model later.
  return lambda feature: encoder(index(feature))

# test on dep
test_dep_col = df['JobSatisfaction']
test_dep_layer = get_category_encoding_layer(name='JobSatisfaction',
                                              dataset=ds_train,
                                              dtype='int64')
print(test_dep_layer(test_dep_col))

# test on education
test_education_col = df['WorkLifeBalance']
test_dep_layer = get_category_encoding_layer(name='WorkLifeBalance',
                                              dataset=ds_train,
                                              dtype='int64')
print(test_dep_layer(test_education_col))
# Out:
# tf.Tensor([0. 1. 1. 1. 1.], shape=(5,), dtype=float32)
# tf.Tensor([0. 1. 1. 1. 1.], shape=(5,), dtype=float32)

# %%
batch_size = 1176

train_ds = df_to_dataset(train, batch_size=batch_size)
val_ds = df_to_dataset(val, shuffle=False, batch_size=batch_size)
test_ds = df_to_dataset(test, shuffle=False, batch_size=batch_size)

# split categorical and continuous data
# # full data set
# header_continous = ['Age', 'DailyRate', 'DistanceFromHome', 'HourlyRate', 'MonthlyIncome', 'MonthlyRate', 'PercentSalaryHike', 'TotalWorkingYears', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']
# header_categorical = ['Attrition', 'BusinessTravel', 'Department', 'Education','EducationField','EnvironmentSatisfaction','Gender','JobInvolvement','JobLevel','JobRole','JobSatisfaction','MaritalStatus','NumCompaniesWorked', 'OverTime','PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel','TrainingTimesLastYear', 'WorkLifeBalance']
# optimized data
# header_continous = ['Age', 'DistanceFromHome', 'MonthlyIncome', 'TotalWorkingYears', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']
header_continous = ["MonthlyIncome", "BusinessTravel", "StockOptionLevel", "DistanceFromHome", "Age"]
# header_categorical = ['Attrition', 'BusinessTravel', 'Education','EnvironmentSatisfaction','JobInvolvement','JobLevel','JobSatisfaction','MaritalStatus','NumCompaniesWorked', 'OverTime','PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel','TrainingTimesLastYear', 'WorkLifeBalance']
header_categorical = ['JobSatisfaction','EnvironmentSatisfaction','JobInvolvement','PerformanceRating', 'RelationshipSatisfaction', 'WorkLifeBalance']
# Out:
# C:\Users\siman\AppData\Local\Temp\ipykernel_936\548746522.py:5: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   _df = {key: value[:,tf.newaxis] for key, value in dataframe.items()}
# C:\Users\siman\AppData\Local\Temp\ipykernel_936\548746522.py:5: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   _df = {key: value[:,tf.newaxis] for key, value in dataframe.items()}
# C:\Users\siman\AppData\Local\Temp\ipykernel_936\548746522.py:5: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   _df = {key: value[:,tf.newaxis] for key, value in dataframe.items()}

# %%
all_inputs = []
encoded_features = []
encoded_numerical = []
encoded_categorical = []
encoded_survey = []

use_continous = True

# Numerical features.
if use_continous:
  for header in header_continous:
    numeric_col = tf.keras.Input(shape=(1,), name=header)
    normalization_layer = get_normalization_layer(header, train_ds)
    encoded_numeric_col = normalization_layer(numeric_col)
    all_inputs.append(numeric_col)
    encoded_features.append(encoded_numeric_col)
    encoded_numerical.append(encoded_numeric_col)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [30], line 13
#      11 for header in header_continous:
#      12   numeric_col = tf.keras.Input(shape=(1,), name=header)
# ---> 13   normalization_layer = get_normalization_layer(header, train_ds)
#      14   encoded_numeric_col = normalization_layer(numeric_col)
#      15   all_inputs.append(numeric_col)
#
# Cell In [21], line 6, in get_normalization_layer(name, dataset)
#       3 normalizer = layers.Normalization(axis=None)
#       5 # Prepare a Dataset that only yields the feature.
# ----> 6 feature_ds = dataset.map(lambda x, y: x[name])
#       8 # Learn the statistics of the data.
#       9 normalizer.adapt(feature_ds)
#
# File c:\Users\siman\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:2294, in DatasetV2.map(self, map_func, num_parallel_calls, deterministic, name)
#    2291   if deterministic is not None and not DEBUG_MODE:
#    2292     warnings.warn("The `deterministic` argument has no effect unless the "
#    2293                   "`num_parallel_calls` argument is specified.")
# -> 2294   return MapDataset(self, map_func, preserve_cardinality=True, name=name)
#    2295 else:
#    2296   return ParallelMapDataset(
#    2297       self,
#    2298       map_func,
#    (...)
#    2301       preserve_cardinality=True,
#    2302       name=name)
#
# File c:\Users\siman\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:5499, in MapDataset.__init__(self, input_dataset, map_func, use_inter_op_parallelism, preserve_cardinality, use_legacy_function, name)
#    5497 self._use_inter_op_parallelism = use_inter_op_parallelism
#    5498 self._preserve_cardinality = preserve_cardinality
# -> 5499 self._map_func = structured_function.StructuredFunctionWrapper(
#    5500     map_func,
#    5501     self._transformation_name(),
#    5502     dataset=input_dataset,
#    5503     use_legacy_function=use_legacy_function)
#    5504 self._name = name
#    5505 variant_tensor = gen_dataset_ops.map_dataset(
#    5506     input_dataset._variant_tensor,  # pylint: disable=protected-access
#    5507     self._map_func.function.captured_inputs,
#    (...)
#    5510     preserve_cardinality=self._preserve_cardinality,
#    5511     **self._common_args)
#
# File c:\Users\siman\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\ops\structured_function.py:263, in StructuredFunctionWrapper.__init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#     256       warnings.warn(
#     257           "Even though the `tf.config.experimental_run_functions_eagerly` "
#     258           "option is set, this option does not apply to tf.data functions. "
#     259           "To force eager execution of tf.data functions, please use "
#     260           "`tf.data.experimental.enable_debug_mode()`.")
#     261     fn_factory = trace_tf_function(defun_kwargs)
# --> 263 self._function = fn_factory()
#     264 # There is no graph to add in eager mode.
#     265 add_to_graph &= not context.executing_eagerly()
#
# File c:\Users\siman\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:226, in TracingCompiler.get_concrete_function(self, *args, **kwargs)
#     217 def get_concrete_function(self, *args, **kwargs):
#     218   """Returns a `ConcreteFunction` specialized to inputs and execution context.
#     219
#     220   Args:
#    (...)
#     224       `tf.Tensor` or `tf.TensorSpec`.
#     225   """
# --> 226   concrete_function = self._get_concrete_function_garbage_collected(
#     227       *args, **kwargs)
#     228   concrete_function._garbage_collector.release()  # pylint: disable=protected-access
#     229   return concrete_function
#
# File c:\Users\siman\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:192, in TracingCompiler._get_concrete_function_garbage_collected(self, *args, **kwargs)
#     189   self._function_spec.validate_inputs_with_signature(args, kwargs)
#     191 with self._lock:
# --> 192   concrete_function, _ = self._maybe_define_concrete_function(args, kwargs)
#     193   seen_names = set()
#     194   captured = object_identity.ObjectIdentitySet(
#     195       concrete_function.graph.internal_captures)
#
# File c:\Users\siman\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:157, in TracingCompiler._maybe_define_concrete_function(self, args, kwargs)
#     154   args = self.input_signature
#     155   kwargs = {}
# --> 157 return self._maybe_define_function(args, kwargs)
#
# File c:\Users\siman\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:360, in TracingCompiler._maybe_define_function(self, args, kwargs)
#     357   # Only get placeholders for arguments, not captures
#     358   args, kwargs = generalized_func_key._placeholder_value()  # pylint: disable=protected-access
# --> 360 concrete_function = self._create_concrete_function(args, kwargs)
#     362 graph_capture_container = concrete_function.graph._capture_func_lib  # pylint: disable=protected-access
#     363 # Maintain the list of all captures
#
# File c:\Users\siman\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:284, in TracingCompiler._create_concrete_function(self, args, kwargs)
#     279 missing_arg_names = [
#     280     "%s_%d" % (arg, i) for i, arg in enumerate(missing_arg_names)
#     281 ]
#     282 arg_names = base_arg_names + missing_arg_names
#     283 concrete_function = monomorphic_function.ConcreteFunction(
# --> 284     func_graph_module.func_graph_from_py_func(
#     285         self._name,
#     286         self._python_function,
#     287         args,
#     288         kwargs,
#     289         None,
#     290         autograph=self._autograph,
#     291         autograph_options=self._autograph_options,
#     292         arg_names=arg_names,
#     293         capture_by_value=self._capture_by_value),
#     294     self._function_attributes,
#     295     spec=self.function_spec,
#     296     # Tell the ConcreteFunction to clean up its graph once it goes out of
#     297     # scope. This is not the default behavior since it gets used in some
#     298     # places (like Keras) where the FuncGraph lives longer than the
#     299     # ConcreteFunction.
#     300     shared_func_graph=False)
#     301 return concrete_function
#
# File c:\Users\siman\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\framework\func_graph.py:1283, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, acd_record_initial_resource_uses)
#    1280 else:
#    1281   _, original_func = tf_decorator.unwrap(python_func)
# -> 1283 func_outputs = python_func(*func_args, **func_kwargs)
#    1285 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1286 # TensorArrays and `None`s.
#    1287 func_outputs = variable_utils.convert_variables_to_tensors(func_outputs)
#
# File c:\Users\siman\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\ops\structured_function.py:240, in StructuredFunctionWrapper.__init__.<locals>.trace_tf_function.<locals>.wrapped_fn(*args)
#     234 @eager_function.defun_with_attributes(
#     235     input_signature=structure.get_flat_tensor_specs(
#     236         self._input_structure),
#     237     autograph=False,
#     238     attributes=defun_kwargs)
#     239 def wrapped_fn(*args):  # pylint: disable=missing-docstring
# --> 240   ret = wrapper_helper(*args)
#     241   ret = structure.to_tensor_list(self._output_structure, ret)
#     242   return [ops.convert_to_tensor(t) for t in ret]
#
# File c:\Users\siman\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\ops\structured_function.py:171, in StructuredFunctionWrapper.__init__.<locals>.wrapper_helper(*args)
#     169 if not _should_unpack(nested_args):
#     170   nested_args = (nested_args,)
# --> 171 ret = autograph.tf_convert(self._func, ag_ctx)(*nested_args)
#     172 ret = variable_utils.convert_variables_to_tensors(ret)
#     173 if _should_pack(ret):
#
# File c:\Users\siman\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\autograph\impl\api.py:692, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     690 except Exception as e:  # pylint:disable=broad-except
#     691   if hasattr(e, 'ag_error_metadata'):
# --> 692     raise e.ag_error_metadata.to_exception(e)
#     693   else:
#     694     raise
#
# File c:\Users\siman\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\autograph\impl\api.py:689, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     687 try:
#     688   with conversion_ctx:
# --> 689     return converted_call(f, args, kwargs, options=options)
#     690 except Exception as e:  # pylint:disable=broad-except
#     691   if hasattr(e, 'ag_error_metadata'):
#
# File c:\Users\siman\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\autograph\impl\api.py:439, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     437 try:
#     438   if kwargs is not None:
# --> 439     result = converted_f(*effective_args, **kwargs)
#     440   else:
#     441     result = converted_f(*effective_args)
#
# File ~\AppData\Local\Temp\__autograph_generated_filexw0m7u36.py:6, in outer_factory.<locals>.inner_factory.<locals>.<lambda>(x, y)
#       5 def inner_factory(ag__):
# ----> 6     tf__lam = lambda x, y: ag__.with_function_scope(lambda lscope: x[name], 'lscope', ag__.STD)
#       7     return tf__lam
#
# File c:\Users\siman\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\autograph\core\function_wrappers.py:113, in with_function_scope(thunk, scope_name, options)
#     111 """Inline version of the FunctionScope context manager."""
#     112 with FunctionScope('lambda_', scope_name, options) as scope:
# --> 113   return thunk(scope)
#
# File ~\AppData\Local\Temp\__autograph_generated_filexw0m7u36.py:6, in outer_factory.<locals>.inner_factory.<locals>.<lambda>(lscope)
#       5 def inner_factory(ag__):
# ----> 6     tf__lam = lambda x, y: ag__.with_function_scope(lambda lscope: x[name], 'lscope', ag__.STD)
#       7     return tf__lam
#
# KeyError: in user code:
#
#     File "C:\Users\siman\AppData\Local\Temp\ipykernel_936\4204249637.py", line 6, in None  *
#         lambda x, y: x[name]
#
#     KeyError: 'Age'

# %%
for header in header_categorical:
  categorical_col = tf.keras.Input(shape=(1,), name=header, dtype='int64')
  encoding_layer = get_category_encoding_layer(name=header,
                                               dataset=train_ds,
                                               dtype='int64',
                                               max_tokens=None)
  encoded_categorical_col = encoding_layer(categorical_col)
  all_inputs.append(categorical_col)
  encoded_features.append(encoded_categorical_col)
  encoded_categorical.append(encoded_categorical_col)

# %%
all_features = tf.keras.layers.concatenate(encoded_features)
# categorical_features = tf.keras.layers.concatenate(encoded_categorical)
# if use_continous:
#     numerical_features = tf.keras.layers.concatenate(encoded_numerical)

# if use_continous:
#     x1 = tf.keras.layers.Dense(15, activation="relu", kernel_initializer=tf.keras.initializers.Zeros())(numerical_features)
# # x1 = tf.keras.layers.Dropout(0.3)(x1)
# x2 = tf.keras.layers.Dense(15, activation="sigmoid")(categorical_features)
# # x2 = tf.keras.layers.Dropout(0.8)(x2)
# if use_continous:
#     x = tf.keras.layers.concatenate([x1, x2])
# else:
#     x=tf.keras.layers.Dense(10, activation="relu")(x2)
# # x = tf.keras.layers.Dense(10, activation="relu")(x)
# x = tf.keras.layers.Dense(7, activation="relu")(x)

x = tf.keras.layers.Dense(129)(all_features)
x = tf.keras.layers.Dense(60)(all_features)
x = tf.keras.layers.Dense(20)(all_features)
x = tf.keras.layers.Dense(8)(x)
output = tf.keras.layers.Dense(1)(x)

model = tf.keras.Model(all_inputs, output)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [14], line 1
# ----> 1 all_features = tf.keras.layers.concatenate(encoded_features)
#       2 # categorical_features = tf.keras.layers.concatenate(encoded_categorical)
#       3 # if use_continous:
#       4 #     numerical_features = tf.keras.layers.concatenate(encoded_numerical)
#    (...)
#      15 # # x = tf.keras.layers.Dense(10, activation="relu")(x)
#      16 # x = tf.keras.layers.Dense(7, activation="relu")(x)
#      18 x = tf.keras.layers.Dense(129)(all_features)
#
# NameError: name 'encoded_features' is not defined

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=False),
              metrics=['accuracy', tf.keras.metrics.TruePositives(), tf.keras.metrics.TrueNegatives(), tf.keras.metrics.FalsePositives(), tf.keras.metrics.FalseNegatives()])

# %%
# Use `rankdir='LR'` to make the graph horizontal.
tf.keras.utils.plot_model(model, show_shapes=True, rankdir="LR")

# %%
model.fit(train_ds, epochs=100, validation_data=val_ds)
# Out:
# Epoch 1/100
# c:\Users\siman\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\functional.py:638: UserWarning: Input dict contained keys ['Unnamed: 0', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department', 'Education', 'EducationField', 'Gender', 'HourlyRate', 'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager'] which did not match any model input. They will be ignored by the model.
#   inputs = self._flatten_to_reference_inputs(inputs)
# 1/1 [==============================] - 1s 1s/step - loss: 1.9309 - accuracy: 0.7202 - true_positives_19: 27.0000 - true_negatives_19: 820.0000 - false_positives_18: 174.0000 - false_negatives_18: 155.0000 - val_loss: 2.1134 - val_accuracy: 0.7075 - val_true_positives_19: 2.0000 - val_true_negatives_19: 102.0000 - val_false_positives_18: 18.0000 - val_false_negatives_18: 25.0000
# Epoch 2/100
# 1/1 [==============================] - 0s 52ms/step - loss: 1.8547 - accuracy: 0.7415 - true_positives_19: 24.0000 - true_negatives_19: 848.0000 - false_positives_18: 146.0000 - false_negatives_18: 158.0000 - val_loss: 2.0231 - val_accuracy: 0.7279 - val_true_positives_19: 2.0000 - val_true_negatives_19: 105.0000 - val_false_positives_18: 15.0000 - val_false_negatives_18: 25.0000
# Epoch 3/100
# 1/1 [==============================] - 0s 52ms/step - loss: 1.8660 - accuracy: 0.7517 - true_positives_19: 23.0000 - true_negatives_19: 861.0000 - false_positives_18: 133.0000 - false_negatives_18: 159.0000 - val_loss: 1.9429 - val_accuracy: 0.7483 - val_true_positives_19: 2.0000 - val_true_negatives_19: 108.0000 - val_false_positives_18: 12.0000 - val_false_negatives_18: 25.0000
# Epoch 4/100
# 1/1 [==============================] - 0s 62ms/step - loss: 1.8607 - accuracy: 0.7670 - true_positives_19: 21.0000 - true_negatives_19: 881.0000 - false_positives_18: 113.0000 - false_negatives_18: 161.0000 - val_loss: 2.0112 - val_accuracy: 0.7551 - val_true_positives_19: 2.0000 - val_true_negatives_19: 109.0000 - val_false_positives_18: 11.0000 - val_false_negatives_18: 25.0000
# Epoch 5/100
# 1/1 [==============================] - 0s 57ms/step - loss: 1.8334 - accuracy: 0.7730 - true_positives_19: 20.0000 - true_negatives_19: 889.0000 - false_positives_18: 105.0000 - false_negatives_18: 162.0000 - val_loss: 2.0895 - val_accuracy: 0.7483 - val_true_positives_19: 1.0000 - val_true_negatives_19: 109.0000 - val_false_positives_18: 11.0000 - val_false_negatives_18: 26.0000
# Epoch 6/100
# 1/1 [==============================] - 0s 54ms/step - loss: 1.8218 - accuracy: 0.7806 - true_positives_19: 19.0000 - true_negatives_19: 899.0000 - false_positives_18: 95.0000 - false_negatives_18: 163.0000 - val_loss: 2.1529 - val_accuracy: 0.7483 - val_true_positives_19: 1.0000 - val_true_negatives_19: 109.0000 - val_false_positives_18: 11.0000 - val_false_negatives_18: 26.0000
# Epoch 7/100
# 1/1 [==============================] - 0s 50ms/step - loss: 1.8093 - accuracy: 0.7849 - true_positives_19: 18.0000 - true_negatives_19: 905.0000 - false_positives_18: 89.0000 - false_negatives_18: 164.0000 - val_loss: 2.0813 - val_accuracy: 0.7551 - val_true_positives_19: 1.0000 - val_true_negatives_19: 110.0000 - val_false_positives_18: 10.0000 - val_false_negatives_18: 26.0000
# Epoch 8/100
# 1/1 [==============================] - 0s 53ms/step - loss: 1.8203 - accuracy: 0.7900 - true_positives_19: 18.0000 - true_negatives_19: 911.0000 - false_positives_18: 83.0000 - false_negatives_18: 164.0000 - val_loss: 2.0748 - val_accuracy: 0.7551 - val_true_positives_19: 1.0000 - val_true_negatives_19: 110.0000 - val_false_positives_18: 10.0000 - val_false_negatives_18: 26.0000
# Epoch 9/100
# 1/1 [==============================] - 0s 53ms/step - loss: 1.8130 - accuracy: 0.7934 - true_positives_19: 18.0000 - true_negatives_19: 915.0000 - false_positives_18: 79.0000 - false_negatives_18: 164.0000 - val_loss: 2.0699 - val_accuracy: 0.7551 - val_true_positives_19: 1.0000 - val_true_negatives_19: 110.0000 - val_false_positives_18: 10.0000 - val_false_negatives_18: 26.0000
# Epoch 10/100
# 1/1 [==============================] - 0s 57ms/step - loss: 1.8077 - accuracy: 0.7959 - true_positives_19: 18.0000 - true_negatives_19: 918.0000 - false_positives_18: 76.0000 - false_negatives_18: 164.0000 - val_loss: 2.0656 - val_accuracy: 0.7551 - val_true_positives_19: 1.0000 - val_true_negatives_19: 110.0000 - val_false_positives_18: 10.0000 - val_false_negatives_18: 26.0000
# Epoch 11/100
# 1/1 [==============================] - 0s 58ms/step - loss: 1.8038 - accuracy: 0.7976 - true_positives_19: 18.0000 - true_negatives_19: 920.0000 - false_positives_18: 74.0000 - false_negatives_18: 164.0000 - val_loss: 2.0620 - val_accuracy: 0.7619 - val_true_positives_19: 1.0000 - val_true_negatives_19: 111.0000 - val_false_positives_18: 9.0000 - val_false_negatives_18: 26.0000
# Epoch 12/100
# 1/1 [==============================] - 0s 58ms/step - loss: 1.8011 - accuracy: 0.8010 - true_positives_19: 17.0000 - true_negatives_19: 925.0000 - false_positives_18: 69.0000 - false_negatives_18: 165.0000 - val_loss: 2.0589 - val_accuracy: 0.7619 - val_true_positives_19: 1.0000 - val_true_negatives_19: 111.0000 - val_false_positives_18: 9.0000 - val_false_negatives_18: 26.0000
# Epoch 13/100
# 1/1 [==============================] - 0s 53ms/step - loss: 1.8068 - accuracy: 0.8053 - true_positives_19: 17.0000 - true_negatives_19: 930.0000 - false_positives_18: 64.0000 - false_negatives_18: 165.0000 - val_loss: 2.0561 - val_accuracy: 0.7619 - val_true_positives_19: 1.0000 - val_true_negatives_19: 111.0000 - val_false_positives_18: 9.0000 - val_false_negatives_18: 26.0000
# Epoch 14/100
# 1/1 [==============================] - 0s 53ms/step - loss: 1.7959 - accuracy: 0.8053 - true_positives_19: 16.0000 - true_negatives_19: 931.0000 - false_positives_18: 63.0000 - false_negatives_18: 166.0000 - val_loss: 2.0538 - val_accuracy: 0.7619 - val_true_positives_19: 1.0000 - val_true_negatives_19: 111.0000 - val_false_positives_18: 9.0000 - val_false_negatives_18: 26.0000
# Epoch 15/100
# 1/1 [==============================] - 0s 55ms/step - loss: 1.8012 - accuracy: 0.8053 - true_positives_19: 16.0000 - true_negatives_19: 931.0000 - false_positives_18: 63.0000 - false_negatives_18: 166.0000 - val_loss: 2.0519 - val_accuracy: 0.7619 - val_true_positives_19: 1.0000 - val_true_negatives_19: 111.0000 - val_false_positives_18: 9.0000 - val_false_negatives_18: 26.0000
# Epoch 16/100
# 1/1 [==============================] - 0s 60ms/step - loss: 1.7983 - accuracy: 0.8061 - true_positives_19: 14.0000 - true_negatives_19: 934.0000 - false_positives_18: 60.0000 - false_negatives_18: 168.0000 - val_loss: 2.0502 - val_accuracy: 0.7619 - val_true_positives_19: 1.0000 - val_true_negatives_19: 111.0000 - val_false_positives_18: 9.0000 - val_false_negatives_18: 26.0000
# Epoch 17/100
# 1/1 [==============================] - 0s 53ms/step - loss: 1.7957 - accuracy: 0.8070 - true_positives_19: 14.0000 - true_negatives_19: 935.0000 - false_positives_18: 59.0000 - false_negatives_18: 168.0000 - val_loss: 2.0488 - val_accuracy: 0.7687 - val_true_positives_19: 1.0000 - val_true_negatives_19: 112.0000 - val_false_positives_18: 8.0000 - val_false_negatives_18: 26.0000
# Epoch 18/100
# 1/1 [==============================] - 0s 53ms/step - loss: 1.7847 - accuracy: 0.8078 - true_positives_19: 14.0000 - true_negatives_19: 936.0000 - false_positives_18: 58.0000 - false_negatives_18: 168.0000 - val_loss: 2.0475 - val_accuracy: 0.7687 - val_true_positives_19: 1.0000 - val_true_negatives_19: 112.0000 - val_false_positives_18: 8.0000 - val_false_negatives_18: 26.0000
# Epoch 19/100
# 1/1 [==============================] - 0s 54ms/step - loss: 1.7818 - accuracy: 0.8095 - true_positives_19: 13.0000 - true_negatives_19: 939.0000 - false_positives_18: 55.0000 - false_negatives_18: 169.0000 - val_loss: 2.0464 - val_accuracy: 0.7687 - val_true_positives_19: 1.0000 - val_true_negatives_19: 112.0000 - val_false_positives_18: 8.0000 - val_false_negatives_18: 26.0000
# Epoch 20/100
# 1/1 [==============================] - 0s 55ms/step - loss: 1.7793 - accuracy: 0.8104 - true_positives_19: 12.0000 - true_negatives_19: 941.0000 - false_positives_18: 53.0000 - false_negatives_18: 170.0000 - val_loss: 2.0455 - val_accuracy: 0.7687 - val_true_positives_19: 1.0000 - val_true_negatives_19: 112.0000 - val_false_positives_18: 8.0000 - val_false_negatives_18: 26.0000
# Epoch 21/100
# 1/1 [==============================] - 0s 58ms/step - loss: 1.7772 - accuracy: 0.8121 - true_positives_19: 11.0000 - true_negatives_19: 944.0000 - false_positives_18: 50.0000 - false_negatives_18: 171.0000 - val_loss: 2.0449 - val_accuracy: 0.7687 - val_true_positives_19: 1.0000 - val_true_negatives_19: 112.0000 - val_false_positives_18: 8.0000 - val_false_negatives_18: 26.0000
# Epoch 22/100
# 1/1 [==============================] - 0s 52ms/step - loss: 1.7754 - accuracy: 0.8121 - true_positives_19: 11.0000 - true_negatives_19: 944.0000 - false_positives_18: 50.0000 - false_negatives_18: 171.0000 - val_loss: 2.0444 - val_accuracy: 0.7687 - val_true_positives_19: 1.0000 - val_true_negatives_19: 112.0000 - val_false_positives_18: 8.0000 - val_false_negatives_18: 26.0000
# Epoch 23/100
# 1/1 [==============================] - 0s 57ms/step - loss: 1.7738 - accuracy: 0.8146 - true_positives_19: 11.0000 - true_negatives_19: 947.0000 - false_positives_18: 47.0000 - false_negatives_18: 171.0000 - val_loss: 2.0441 - val_accuracy: 0.7687 - val_true_positives_19: 1.0000 - val_true_negatives_19: 112.0000 - val_false_positives_18: 8.0000 - val_false_negatives_18: 26.0000
# Epoch 24/100
# 1/1 [==============================] - 0s 52ms/step - loss: 1.7725 - accuracy: 0.8146 - true_positives_19: 10.0000 - true_negatives_19: 948.0000 - false_positives_18: 46.0000 - false_negatives_18: 172.0000 - val_loss: 2.0438 - val_accuracy: 0.7687 - val_true_positives_19: 1.0000 - val_true_negatives_19: 112.0000 - val_false_positives_18: 8.0000 - val_false_negatives_18: 26.0000
# Epoch 25/100
# 1/1 [==============================] - 0s 61ms/step - loss: 1.7712 - accuracy: 0.8146 - true_positives_19: 10.0000 - true_negatives_19: 948.0000 - false_positives_18: 46.0000 - false_negatives_18: 172.0000 - val_loss: 2.0434 - val_accuracy: 0.7687 - val_true_positives_19: 1.0000 - val_true_negatives_19: 112.0000 - val_false_positives_18: 8.0000 - val_false_negatives_18: 26.0000
# Epoch 26/100
# 1/1 [==============================] - 0s 54ms/step - loss: 1.7699 - accuracy: 0.8155 - true_positives_19: 10.0000 - true_negatives_19: 949.0000 - false_positives_18: 45.0000 - false_negatives_18: 172.0000 - val_loss: 2.0429 - val_accuracy: 0.7687 - val_true_positives_19: 1.0000 - val_true_negatives_19: 112.0000 - val_false_positives_18: 8.0000 - val_false_negatives_18: 26.0000
# Epoch 27/100
# 1/1 [==============================] - 0s 51ms/step - loss: 1.7687 - accuracy: 0.8163 - true_positives_19: 10.0000 - true_negatives_19: 950.0000 - false_positives_18: 44.0000 - false_negatives_18: 172.0000 - val_loss: 2.0423 - val_accuracy: 0.7687 - val_true_positives_19: 1.0000 - val_true_negatives_19: 112.0000 - val_false_positives_18: 8.0000 - val_false_negatives_18: 26.0000
# Epoch 28/100
# 1/1 [==============================] - 0s 54ms/step - loss: 1.7675 - accuracy: 0.8197 - true_positives_19: 10.0000 - true_negatives_19: 954.0000 - false_positives_18: 40.0000 - false_negatives_18: 172.0000 - val_loss: 2.0416 - val_accuracy: 0.7687 - val_true_positives_19: 1.0000 - val_true_negatives_19: 112.0000 - val_false_positives_18: 8.0000 - val_false_negatives_18: 26.0000
# Epoch 29/100
# 1/1 [==============================] - 0s 68ms/step - loss: 1.7663 - accuracy: 0.8197 - true_positives_19: 10.0000 - true_negatives_19: 954.0000 - false_positives_18: 40.0000 - false_negatives_18: 172.0000 - val_loss: 2.0407 - val_accuracy: 0.7687 - val_true_positives_19: 1.0000 - val_true_negatives_19: 112.0000 - val_false_positives_18: 8.0000 - val_false_negatives_18: 26.0000
# Epoch 30/100
# 1/1 [==============================] - 0s 59ms/step - loss: 1.7653 - accuracy: 0.8197 - true_positives_19: 10.0000 - true_negatives_19: 954.0000 - false_positives_18: 40.0000 - false_negatives_18: 172.0000 - val_loss: 2.0398 - val_accuracy: 0.7687 - val_true_positives_19: 1.0000 - val_true_negatives_19: 112.0000 - val_false_positives_18: 8.0000 - val_false_negatives_18: 26.0000
# Epoch 31/100
# 1/1 [==============================] - 0s 55ms/step - loss: 1.7643 - accuracy: 0.8206 - true_positives_19: 11.0000 - true_negatives_19: 954.0000 - false_positives_18: 40.0000 - false_negatives_18: 171.0000 - val_loss: 2.0389 - val_accuracy: 0.7687 - val_true_positives_19: 1.0000 - val_true_negatives_19: 112.0000 - val_false_positives_18: 8.0000 - val_false_negatives_18: 26.0000
# Epoch 32/100
# 1/1 [==============================] - 0s 54ms/step - loss: 1.7634 - accuracy: 0.8206 - true_positives_19: 11.0000 - true_negatives_19: 954.0000 - false_positives_18: 40.0000 - false_negatives_18: 171.0000 - val_loss: 2.0379 - val_accuracy: 0.7687 - val_true_positives_19: 1.0000 - val_true_negatives_19: 112.0000 - val_false_positives_18: 8.0000 - val_false_negatives_18: 26.0000
# Epoch 33/100
# 1/1 [==============================] - 0s 57ms/step - loss: 1.7542 - accuracy: 0.8197 - true_positives_19: 11.0000 - true_negatives_19: 953.0000 - false_positives_18: 41.0000 - false_negatives_18: 171.0000 - val_loss: 1.9683 - val_accuracy: 0.7687 - val_true_positives_19: 1.0000 - val_true_negatives_19: 112.0000 - val_false_positives_18: 8.0000 - val_false_negatives_18: 26.0000
# Epoch 34/100
# 1/1 [==============================] - 0s 54ms/step - loss: 1.7523 - accuracy: 0.8197 - true_positives_19: 11.0000 - true_negatives_19: 953.0000 - false_positives_18: 41.0000 - false_negatives_18: 171.0000 - val_loss: 1.9611 - val_accuracy: 0.7687 - val_true_positives_19: 1.0000 - val_true_negatives_19: 112.0000 - val_false_positives_18: 8.0000 - val_false_negatives_18: 26.0000
# Epoch 35/100
# 1/1 [==============================] - 0s 50ms/step - loss: 1.7510 - accuracy: 0.8206 - true_positives_19: 11.0000 - true_negatives_19: 954.0000 - false_positives_18: 40.0000 - false_negatives_18: 171.0000 - val_loss: 1.9570 - val_accuracy: 0.7687 - val_true_positives_19: 1.0000 - val_true_negatives_19: 112.0000 - val_false_positives_18: 8.0000 - val_false_negatives_18: 26.0000
# Epoch 36/100
# 1/1 [==============================] - 0s 54ms/step - loss: 1.7499 - accuracy: 0.8197 - true_positives_19: 10.0000 - true_negatives_19: 954.0000 - false_positives_18: 40.0000 - false_negatives_18: 172.0000 - val_loss: 1.9542 - val_accuracy: 0.7755 - val_true_positives_19: 1.0000 - val_true_negatives_19: 113.0000 - val_false_positives_18: 7.0000 - val_false_negatives_18: 26.0000
# Epoch 37/100
# 1/1 [==============================] - 0s 56ms/step - loss: 1.7489 - accuracy: 0.8214 - true_positives_19: 10.0000 - true_negatives_19: 956.0000 - false_positives_18: 38.0000 - false_negatives_18: 172.0000 - val_loss: 1.9519 - val_accuracy: 0.7755 - val_true_positives_19: 1.0000 - val_true_negatives_19: 113.0000 - val_false_positives_18: 7.0000 - val_false_negatives_18: 26.0000
# Epoch 38/100
# 1/1 [==============================] - 0s 59ms/step - loss: 1.7481 - accuracy: 0.8214 - true_positives_19: 10.0000 - true_negatives_19: 956.0000 - false_positives_18: 38.0000 - false_negatives_18: 172.0000 - val_loss: 1.9502 - val_accuracy: 0.7755 - val_true_positives_19: 1.0000 - val_true_negatives_19: 113.0000 - val_false_positives_18: 7.0000 - val_false_negatives_18: 26.0000
# Epoch 39/100
# 1/1 [==============================] - 0s 53ms/step - loss: 1.7473 - accuracy: 0.8214 - true_positives_19: 10.0000 - true_negatives_19: 956.0000 - false_positives_18: 38.0000 - false_negatives_18: 172.0000 - val_loss: 1.9487 - val_accuracy: 0.7755 - val_true_positives_19: 1.0000 - val_true_negatives_19: 113.0000 - val_false_positives_18: 7.0000 - val_false_negatives_18: 26.0000
# Epoch 40/100
# 1/1 [==============================] - 0s 54ms/step - loss: 1.7466 - accuracy: 0.8223 - true_positives_19: 11.0000 - true_negatives_19: 956.0000 - false_positives_18: 38.0000 - false_negatives_18: 171.0000 - val_loss: 1.9475 - val_accuracy: 0.7755 - val_true_positives_19: 1.0000 - val_true_negatives_19: 113.0000 - val_false_positives_18: 7.0000 - val_false_negatives_18: 26.0000
# Epoch 41/100
# 1/1 [==============================] - 0s 54ms/step - loss: 1.7459 - accuracy: 0.8223 - true_positives_19: 11.0000 - true_negatives_19: 956.0000 - false_positives_18: 38.0000 - false_negatives_18: 171.0000 - val_loss: 1.9466 - val_accuracy: 0.7755 - val_true_positives_19: 1.0000 - val_true_negatives_19: 113.0000 - val_false_positives_18: 7.0000 - val_false_negatives_18: 26.0000
# Epoch 42/100
# 1/1 [==============================] - 0s 54ms/step - loss: 1.7453 - accuracy: 0.8223 - true_positives_19: 11.0000 - true_negatives_19: 956.0000 - false_positives_18: 38.0000 - false_negatives_18: 171.0000 - val_loss: 1.9458 - val_accuracy: 0.7755 - val_true_positives_19: 1.0000 - val_true_negatives_19: 113.0000 - val_false_positives_18: 7.0000 - val_false_negatives_18: 26.0000
# Epoch 43/100
# 1/1 [==============================] - 0s 55ms/step - loss: 1.7447 - accuracy: 0.8231 - true_positives_19: 11.0000 - true_negatives_19: 957.0000 - false_positives_18: 37.0000 - false_negatives_18: 171.0000 - val_loss: 1.9452 - val_accuracy: 0.7755 - val_true_positives_19: 1.0000 - val_true_negatives_19: 113.0000 - val_false_positives_18: 7.0000 - val_false_negatives_18: 26.0000
# Epoch 44/100
# 1/1 [==============================] - 0s 52ms/step - loss: 1.7441 - accuracy: 0.8231 - true_positives_19: 11.0000 - true_negatives_19: 957.0000 - false_positives_18: 37.0000 - false_negatives_18: 171.0000 - val_loss: 1.9447 - val_accuracy: 0.7755 - val_true_positives_19: 1.0000 - val_true_negatives_19: 113.0000 - val_false_positives_18: 7.0000 - val_false_negatives_18: 26.0000
# Epoch 45/100
# 1/1 [==============================] - 0s 58ms/step - loss: 1.7435 - accuracy: 0.8240 - true_positives_19: 11.0000 - true_negatives_19: 958.0000 - false_positives_18: 36.0000 - false_negatives_18: 171.0000 - val_loss: 1.9443 - val_accuracy: 0.7755 - val_true_positives_19: 1.0000 - val_true_negatives_19: 113.0000 - val_false_positives_18: 7.0000 - val_false_negatives_18: 26.0000
# Epoch 46/100
# 1/1 [==============================] - 0s 54ms/step - loss: 1.7430 - accuracy: 0.8240 - true_positives_19: 11.0000 - true_negatives_19: 958.0000 - false_positives_18: 36.0000 - false_negatives_18: 171.0000 - val_loss: 1.9440 - val_accuracy: 0.7755 - val_true_positives_19: 1.0000 - val_true_negatives_19: 113.0000 - val_false_positives_18: 7.0000 - val_false_negatives_18: 26.0000
# Epoch 47/100
# 1/1 [==============================] - 0s 61ms/step - loss: 1.7425 - accuracy: 0.8248 - true_positives_19: 11.0000 - true_negatives_19: 959.0000 - false_positives_18: 35.0000 - false_negatives_18: 171.0000 - val_loss: 1.9438 - val_accuracy: 0.7755 - val_true_positives_19: 1.0000 - val_true_negatives_19: 113.0000 - val_false_positives_18: 7.0000 - val_false_negatives_18: 26.0000
# Epoch 48/100
# 1/1 [==============================] - 0s 53ms/step - loss: 1.7420 - accuracy: 0.8274 - true_positives_19: 11.0000 - true_negatives_19: 962.0000 - false_positives_18: 32.0000 - false_negatives_18: 171.0000 - val_loss: 1.9437 - val_accuracy: 0.7755 - val_true_positives_19: 1.0000 - val_true_negatives_19: 113.0000 - val_false_positives_18: 7.0000 - val_false_negatives_18: 26.0000
# Epoch 49/100
# 1/1 [==============================] - 0s 58ms/step - loss: 1.7416 - accuracy: 0.8282 - true_positives_19: 11.0000 - true_negatives_19: 963.0000 - false_positives_18: 31.0000 - false_negatives_18: 171.0000 - val_loss: 1.9437 - val_accuracy: 0.7755 - val_true_positives_19: 1.0000 - val_true_negatives_19: 113.0000 - val_false_positives_18: 7.0000 - val_false_negatives_18: 26.0000
# Epoch 50/100
# 1/1 [==============================] - 0s 51ms/step - loss: 1.7412 - accuracy: 0.8291 - true_positives_19: 11.0000 - true_negatives_19: 964.0000 - false_positives_18: 30.0000 - false_negatives_18: 171.0000 - val_loss: 1.9437 - val_accuracy: 0.7755 - val_true_positives_19: 1.0000 - val_true_negatives_19: 113.0000 - val_false_positives_18: 7.0000 - val_false_negatives_18: 26.0000
# Epoch 51/100
# 1/1 [==============================] - 0s 57ms/step - loss: 1.7408 - accuracy: 0.8282 - true_positives_19: 10.0000 - true_negatives_19: 964.0000 - false_positives_18: 30.0000 - false_negatives_18: 172.0000 - val_loss: 1.9438 - val_accuracy: 0.7755 - val_true_positives_19: 1.0000 - val_true_negatives_19: 113.0000 - val_false_positives_18: 7.0000 - val_false_negatives_18: 26.0000
# Epoch 52/100
# 1/1 [==============================] - 0s 55ms/step - loss: 1.7405 - accuracy: 0.8274 - true_positives_19: 9.0000 - true_negatives_19: 964.0000 - false_positives_18: 30.0000 - false_negatives_18: 173.0000 - val_loss: 1.9439 - val_accuracy: 0.7755 - val_true_positives_19: 1.0000 - val_true_negatives_19: 113.0000 - val_false_positives_18: 7.0000 - val_false_negatives_18: 26.0000
# Epoch 53/100
# 1/1 [==============================] - 0s 51ms/step - loss: 1.7402 - accuracy: 0.8282 - true_positives_19: 9.0000 - true_negatives_19: 965.0000 - false_positives_18: 29.0000 - false_negatives_18: 173.0000 - val_loss: 1.9440 - val_accuracy: 0.7755 - val_true_positives_19: 1.0000 - val_true_negatives_19: 113.0000 - val_false_positives_18: 7.0000 - val_false_negatives_18: 26.0000
# Epoch 54/100
# 1/1 [==============================] - 0s 55ms/step - loss: 1.7399 - accuracy: 0.8282 - true_positives_19: 9.0000 - true_negatives_19: 965.0000 - false_positives_18: 29.0000 - false_negatives_18: 173.0000 - val_loss: 1.9441 - val_accuracy: 0.7755 - val_true_positives_19: 1.0000 - val_true_negatives_19: 113.0000 - val_false_positives_18: 7.0000 - val_false_negatives_18: 26.0000
# Epoch 55/100
# 1/1 [==============================] - 0s 51ms/step - loss: 1.7396 - accuracy: 0.8282 - true_positives_19: 9.0000 - true_negatives_19: 965.0000 - false_positives_18: 29.0000 - false_negatives_18: 173.0000 - val_loss: 1.9441 - val_accuracy: 0.7755 - val_true_positives_19: 1.0000 - val_true_negatives_19: 113.0000 - val_false_positives_18: 7.0000 - val_false_negatives_18: 26.0000
# Epoch 56/100
# 1/1 [==============================] - 0s 53ms/step - loss: 1.7393 - accuracy: 0.8282 - true_positives_19: 9.0000 - true_negatives_19: 965.0000 - false_positives_18: 29.0000 - false_negatives_18: 173.0000 - val_loss: 1.9442 - val_accuracy: 0.7755 - val_true_positives_19: 1.0000 - val_true_negatives_19: 113.0000 - val_false_positives_18: 7.0000 - val_false_negatives_18: 26.0000
# Epoch 57/100
# 1/1 [==============================] - 0s 55ms/step - loss: 1.7390 - accuracy: 0.8291 - true_positives_19: 9.0000 - true_negatives_19: 966.0000 - false_positives_18: 28.0000 - false_negatives_18: 173.0000 - val_loss: 1.9442 - val_accuracy: 0.7755 - val_true_positives_19: 1.0000 - val_true_negatives_19: 113.0000 - val_false_positives_18: 7.0000 - val_false_negatives_18: 26.0000
# Epoch 58/100
# 1/1 [==============================] - 0s 48ms/step - loss: 1.7386 - accuracy: 0.8291 - true_positives_19: 9.0000 - true_negatives_19: 966.0000 - false_positives_18: 28.0000 - false_negatives_18: 173.0000 - val_loss: 1.9443 - val_accuracy: 0.7755 - val_true_positives_19: 1.0000 - val_true_negatives_19: 113.0000 - val_false_positives_18: 7.0000 - val_false_negatives_18: 26.0000
# Epoch 59/100
# 1/1 [==============================] - 0s 59ms/step - loss: 1.7383 - accuracy: 0.8291 - true_positives_19: 9.0000 - true_negatives_19: 966.0000 - false_positives_18: 28.0000 - false_negatives_18: 173.0000 - val_loss: 1.9444 - val_accuracy: 0.7755 - val_true_positives_19: 1.0000 - val_true_negatives_19: 113.0000 - val_false_positives_18: 7.0000 - val_false_negatives_18: 26.0000
# Epoch 60/100
# 1/1 [==============================] - 0s 51ms/step - loss: 1.7380 - accuracy: 0.8291 - true_positives_19: 9.0000 - true_negatives_19: 966.0000 - false_positives_18: 28.0000 - false_negatives_18: 173.0000 - val_loss: 1.9446 - val_accuracy: 0.7755 - val_true_positives_19: 1.0000 - val_true_negatives_19: 113.0000 - val_false_positives_18: 7.0000 - val_false_negatives_18: 26.0000
# Epoch 61/100
# 1/1 [==============================] - 0s 55ms/step - loss: 1.7377 - accuracy: 0.8291 - true_positives_19: 9.0000 - true_negatives_19: 966.0000 - false_positives_18: 28.0000 - false_negatives_18: 173.0000 - val_loss: 1.9449 - val_accuracy: 0.7755 - val_true_positives_19: 1.0000 - val_true_negatives_19: 113.0000 - val_false_positives_18: 7.0000 - val_false_negatives_18: 26.0000
# Epoch 62/100
# 1/1 [==============================] - 0s 53ms/step - loss: 1.7302 - accuracy: 0.8291 - true_positives_19: 9.0000 - true_negatives_19: 966.0000 - false_positives_18: 28.0000 - false_negatives_18: 173.0000 - val_loss: 1.9443 - val_accuracy: 0.7755 - val_true_positives_19: 1.0000 - val_true_negatives_19: 113.0000 - val_false_positives_18: 7.0000 - val_false_negatives_18: 26.0000
# Epoch 63/100
# 1/1 [==============================] - 0s 61ms/step - loss: 1.7276 - accuracy: 0.8282 - true_positives_19: 9.0000 - true_negatives_19: 965.0000 - false_positives_18: 29.0000 - false_negatives_18: 173.0000 - val_loss: 1.9441 - val_accuracy: 0.7755 - val_true_positives_19: 1.0000 - val_true_negatives_19: 113.0000 - val_false_positives_18: 7.0000 - val_false_negatives_18: 26.0000
# Epoch 64/100
# 1/1 [==============================] - 0s 50ms/step - loss: 1.7203 - accuracy: 0.8282 - true_positives_19: 9.0000 - true_negatives_19: 965.0000 - false_positives_18: 29.0000 - false_negatives_18: 173.0000 - val_loss: 1.9435 - val_accuracy: 0.7755 - val_true_positives_19: 1.0000 - val_true_negatives_19: 113.0000 - val_false_positives_18: 7.0000 - val_false_negatives_18: 26.0000
# Epoch 65/100
# 1/1 [==============================] - 0s 50ms/step - loss: 1.7087 - accuracy: 0.8282 - true_positives_19: 9.0000 - true_negatives_19: 965.0000 - false_positives_18: 29.0000 - false_negatives_18: 173.0000 - val_loss: 1.9430 - val_accuracy: 0.7755 - val_true_positives_19: 1.0000 - val_true_negatives_19: 113.0000 - val_false_positives_18: 7.0000 - val_false_negatives_18: 26.0000
# Epoch 66/100
# 1/1 [==============================] - 0s 51ms/step - loss: 1.7072 - accuracy: 0.8291 - true_positives_19: 11.0000 - true_negatives_19: 964.0000 - false_positives_18: 30.0000 - false_negatives_18: 171.0000 - val_loss: 1.9432 - val_accuracy: 0.7755 - val_true_positives_19: 1.0000 - val_true_negatives_19: 113.0000 - val_false_positives_18: 7.0000 - val_false_negatives_18: 26.0000
# Epoch 67/100
# 1/1 [==============================] - 0s 60ms/step - loss: 1.7065 - accuracy: 0.8282 - true_positives_19: 11.0000 - true_negatives_19: 963.0000 - false_positives_18: 31.0000 - false_negatives_18: 171.0000 - val_loss: 1.9443 - val_accuracy: 0.7755 - val_true_positives_19: 1.0000 - val_true_negatives_19: 113.0000 - val_false_positives_18: 7.0000 - val_false_negatives_18: 26.0000
# Epoch 68/100
# 1/1 [==============================] - 0s 54ms/step - loss: 1.6995 - accuracy: 0.8291 - true_positives_19: 12.0000 - true_negatives_19: 963.0000 - false_positives_18: 31.0000 - false_negatives_18: 170.0000 - val_loss: 1.8694 - val_accuracy: 0.7755 - val_true_positives_19: 1.0000 - val_true_negatives_19: 113.0000 - val_false_positives_18: 7.0000 - val_false_negatives_18: 26.0000
# Epoch 69/100
# 1/1 [==============================] - 0s 56ms/step - loss: 1.6966 - accuracy: 0.8299 - true_positives_19: 13.0000 - true_negatives_19: 963.0000 - false_positives_18: 31.0000 - false_negatives_18: 169.0000 - val_loss: 1.8688 - val_accuracy: 0.7755 - val_true_positives_19: 1.0000 - val_true_negatives_19: 113.0000 - val_false_positives_18: 7.0000 - val_false_negatives_18: 26.0000
# Epoch 70/100
# 1/1 [==============================] - 0s 52ms/step - loss: 1.6891 - accuracy: 0.8282 - true_positives_19: 13.0000 - true_negatives_19: 961.0000 - false_positives_18: 33.0000 - false_negatives_18: 169.0000 - val_loss: 1.8621 - val_accuracy: 0.7755 - val_true_positives_19: 1.0000 - val_true_negatives_19: 113.0000 - val_false_positives_18: 7.0000 - val_false_negatives_18: 26.0000
# Epoch 71/100
# 1/1 [==============================] - 0s 57ms/step - loss: 1.6640 - accuracy: 0.8265 - true_positives_19: 14.0000 - true_negatives_19: 958.0000 - false_positives_18: 36.0000 - false_negatives_18: 168.0000 - val_loss: 1.8564 - val_accuracy: 0.7755 - val_true_positives_19: 1.0000 - val_true_negatives_19: 113.0000 - val_false_positives_18: 7.0000 - val_false_negatives_18: 26.0000
# Epoch 72/100
# 1/1 [==============================] - 0s 51ms/step - loss: 1.6589 - accuracy: 0.8248 - true_positives_19: 14.0000 - true_negatives_19: 956.0000 - false_positives_18: 38.0000 - false_negatives_18: 168.0000 - val_loss: 1.8539 - val_accuracy: 0.7755 - val_true_positives_19: 1.0000 - val_true_negatives_19: 113.0000 - val_false_positives_18: 7.0000 - val_false_negatives_18: 26.0000
# Epoch 73/100
# 1/1 [==============================] - 0s 64ms/step - loss: 1.6311 - accuracy: 0.8223 - true_positives_19: 15.0000 - true_negatives_19: 952.0000 - false_positives_18: 42.0000 - false_negatives_18: 167.0000 - val_loss: 1.8524 - val_accuracy: 0.7687 - val_true_positives_19: 1.0000 - val_true_negatives_19: 112.0000 - val_false_positives_18: 8.0000 - val_false_negatives_18: 26.0000
# Epoch 74/100
# 1/1 [==============================] - 0s 52ms/step - loss: 1.6206 - accuracy: 0.8197 - true_positives_19: 15.0000 - true_negatives_19: 949.0000 - false_positives_18: 45.0000 - false_negatives_18: 167.0000 - val_loss: 1.8519 - val_accuracy: 0.7551 - val_true_positives_19: 1.0000 - val_true_negatives_19: 110.0000 - val_false_positives_18: 10.0000 - val_false_negatives_18: 26.0000
# Epoch 75/100
# 1/1 [==============================] - 0s 57ms/step - loss: 1.6111 - accuracy: 0.8189 - true_positives_19: 17.0000 - true_negatives_19: 946.0000 - false_positives_18: 48.0000 - false_negatives_18: 165.0000 - val_loss: 1.8520 - val_accuracy: 0.7619 - val_true_positives_19: 2.0000 - val_true_negatives_19: 110.0000 - val_false_positives_18: 10.0000 - val_false_negatives_18: 25.0000
# Epoch 76/100
# 1/1 [==============================] - 0s 52ms/step - loss: 1.5972 - accuracy: 0.8155 - true_positives_19: 18.0000 - true_negatives_19: 941.0000 - false_positives_18: 53.0000 - false_negatives_18: 164.0000 - val_loss: 1.8519 - val_accuracy: 0.7551 - val_true_positives_19: 2.0000 - val_true_negatives_19: 109.0000 - val_false_positives_18: 11.0000 - val_false_negatives_18: 25.0000
# Epoch 77/100
# 1/1 [==============================] - 0s 52ms/step - loss: 1.5760 - accuracy: 0.8121 - true_positives_19: 18.0000 - true_negatives_19: 937.0000 - false_positives_18: 57.0000 - false_negatives_18: 164.0000 - val_loss: 1.7031 - val_accuracy: 0.7551 - val_true_positives_19: 2.0000 - val_true_negatives_19: 109.0000 - val_false_positives_18: 11.0000 - val_false_negatives_18: 25.0000
# Epoch 78/100
# 1/1 [==============================] - 0s 127ms/step - loss: 1.5586 - accuracy: 0.8104 - true_positives_19: 21.0000 - true_negatives_19: 932.0000 - false_positives_18: 62.0000 - false_negatives_18: 161.0000 - val_loss: 1.6281 - val_accuracy: 0.7551 - val_true_positives_19: 2.0000 - val_true_negatives_19: 109.0000 - val_false_positives_18: 11.0000 - val_false_negatives_18: 25.0000
# Epoch 79/100
# 1/1 [==============================] - 0s 55ms/step - loss: 1.5409 - accuracy: 0.8019 - true_positives_19: 21.0000 - true_negatives_19: 922.0000 - false_positives_18: 72.0000 - false_negatives_18: 161.0000 - val_loss: 1.6149 - val_accuracy: 0.7551 - val_true_positives_19: 2.0000 - val_true_negatives_19: 109.0000 - val_false_positives_18: 11.0000 - val_false_negatives_18: 25.0000
# Epoch 80/100
# 1/1 [==============================] - 0s 53ms/step - loss: 1.5218 - accuracy: 0.7985 - true_positives_19: 23.0000 - true_negatives_19: 916.0000 - false_positives_18: 78.0000 - false_negatives_18: 159.0000 - val_loss: 1.6113 - val_accuracy: 0.7483 - val_true_positives_19: 2.0000 - val_true_negatives_19: 108.0000 - val_false_positives_18: 12.0000 - val_false_negatives_18: 25.0000
# Epoch 81/100
# 1/1 [==============================] - 0s 52ms/step - loss: 1.5226 - accuracy: 0.7925 - true_positives_19: 24.0000 - true_negatives_19: 908.0000 - false_positives_18: 86.0000 - false_negatives_18: 158.0000 - val_loss: 1.5368 - val_accuracy: 0.7415 - val_true_positives_19: 2.0000 - val_true_negatives_19: 107.0000 - val_false_positives_18: 13.0000 - val_false_negatives_18: 25.0000
# Epoch 82/100
# 1/1 [==============================] - 0s 57ms/step - loss: 1.4983 - accuracy: 0.7891 - true_positives_19: 24.0000 - true_negatives_19: 904.0000 - false_positives_18: 90.0000 - false_negatives_18: 158.0000 - val_loss: 1.5310 - val_accuracy: 0.7415 - val_true_positives_19: 2.0000 - val_true_negatives_19: 107.0000 - val_false_positives_18: 13.0000 - val_false_negatives_18: 25.0000
# Epoch 83/100
# 1/1 [==============================] - 0s 62ms/step - loss: 1.4795 - accuracy: 0.7883 - true_positives_19: 25.0000 - true_negatives_19: 902.0000 - false_positives_18: 92.0000 - false_negatives_18: 157.0000 - val_loss: 1.5286 - val_accuracy: 0.7347 - val_true_positives_19: 2.0000 - val_true_negatives_19: 106.0000 - val_false_positives_18: 14.0000 - val_false_negatives_18: 25.0000
# Epoch 84/100
# 1/1 [==============================] - 0s 61ms/step - loss: 1.4685 - accuracy: 0.7857 - true_positives_19: 26.0000 - true_negatives_19: 898.0000 - false_positives_18: 96.0000 - false_negatives_18: 156.0000 - val_loss: 1.5274 - val_accuracy: 0.7347 - val_true_positives_19: 2.0000 - val_true_negatives_19: 106.0000 - val_false_positives_18: 14.0000 - val_false_negatives_18: 25.0000
# Epoch 85/100
# 1/1 [==============================] - 0s 62ms/step - loss: 1.4522 - accuracy: 0.7815 - true_positives_19: 26.0000 - true_negatives_19: 893.0000 - false_positives_18: 101.0000 - false_negatives_18: 156.0000 - val_loss: 1.4550 - val_accuracy: 0.7279 - val_true_positives_19: 2.0000 - val_true_negatives_19: 105.0000 - val_false_positives_18: 15.0000 - val_false_negatives_18: 25.0000
# Epoch 86/100
# 1/1 [==============================] - 0s 53ms/step - loss: 1.4506 - accuracy: 0.7764 - true_positives_19: 26.0000 - true_negatives_19: 887.0000 - false_positives_18: 107.0000 - false_negatives_18: 156.0000 - val_loss: 1.4495 - val_accuracy: 0.7279 - val_true_positives_19: 2.0000 - val_true_negatives_19: 105.0000 - val_false_positives_18: 15.0000 - val_false_negatives_18: 25.0000
# Epoch 87/100
# 1/1 [==============================] - 0s 70ms/step - loss: 1.4420 - accuracy: 0.7747 - true_positives_19: 26.0000 - true_negatives_19: 885.0000 - false_positives_18: 109.0000 - false_negatives_18: 156.0000 - val_loss: 1.4469 - val_accuracy: 0.7279 - val_true_positives_19: 2.0000 - val_true_negatives_19: 105.0000 - val_false_positives_18: 15.0000 - val_false_negatives_18: 25.0000
# Epoch 88/100
# 1/1 [==============================] - 0s 54ms/step - loss: 1.4415 - accuracy: 0.7764 - true_positives_19: 28.0000 - true_negatives_19: 885.0000 - false_positives_18: 109.0000 - false_negatives_18: 154.0000 - val_loss: 1.4450 - val_accuracy: 0.7279 - val_true_positives_19: 2.0000 - val_true_negatives_19: 105.0000 - val_false_positives_18: 15.0000 - val_false_negatives_18: 25.0000
# Epoch 89/100
# 1/1 [==============================] - 0s 56ms/step - loss: 1.4256 - accuracy: 0.7764 - true_positives_19: 28.0000 - true_negatives_19: 885.0000 - false_positives_18: 109.0000 - false_negatives_18: 154.0000 - val_loss: 1.4441 - val_accuracy: 0.7211 - val_true_positives_19: 2.0000 - val_true_negatives_19: 104.0000 - val_false_positives_18: 16.0000 - val_false_negatives_18: 25.0000
# Epoch 90/100
# 1/1 [==============================] - 0s 49ms/step - loss: 1.4230 - accuracy: 0.7755 - true_positives_19: 28.0000 - true_negatives_19: 884.0000 - false_positives_18: 110.0000 - false_negatives_18: 154.0000 - val_loss: 1.4433 - val_accuracy: 0.7075 - val_true_positives_19: 2.0000 - val_true_negatives_19: 102.0000 - val_false_positives_18: 18.0000 - val_false_negatives_18: 25.0000
# Epoch 91/100
# 1/1 [==============================] - 0s 51ms/step - loss: 1.4143 - accuracy: 0.7738 - true_positives_19: 29.0000 - true_negatives_19: 881.0000 - false_positives_18: 113.0000 - false_negatives_18: 153.0000 - val_loss: 1.4424 - val_accuracy: 0.7007 - val_true_positives_19: 2.0000 - val_true_negatives_19: 101.0000 - val_false_positives_18: 19.0000 - val_false_negatives_18: 25.0000
# Epoch 92/100
# 1/1 [==============================] - 0s 69ms/step - loss: 1.4033 - accuracy: 0.7721 - true_positives_19: 29.0000 - true_negatives_19: 879.0000 - false_positives_18: 115.0000 - false_negatives_18: 153.0000 - val_loss: 1.4415 - val_accuracy: 0.7007 - val_true_positives_19: 2.0000 - val_true_negatives_19: 101.0000 - val_false_positives_18: 19.0000 - val_false_negatives_18: 25.0000
# Epoch 93/100
# 1/1 [==============================] - 0s 53ms/step - loss: 1.3924 - accuracy: 0.7713 - true_positives_19: 29.0000 - true_negatives_19: 878.0000 - false_positives_18: 116.0000 - false_negatives_18: 153.0000 - val_loss: 1.4404 - val_accuracy: 0.7007 - val_true_positives_19: 2.0000 - val_true_negatives_19: 101.0000 - val_false_positives_18: 19.0000 - val_false_negatives_18: 25.0000
# Epoch 94/100
# 1/1 [==============================] - 0s 54ms/step - loss: 1.3901 - accuracy: 0.7713 - true_positives_19: 29.0000 - true_negatives_19: 878.0000 - false_positives_18: 116.0000 - false_negatives_18: 153.0000 - val_loss: 1.4391 - val_accuracy: 0.7007 - val_true_positives_19: 2.0000 - val_true_negatives_19: 101.0000 - val_false_positives_18: 19.0000 - val_false_negatives_18: 25.0000
# Epoch 95/100
# 1/1 [==============================] - 0s 52ms/step - loss: 1.3828 - accuracy: 0.7713 - true_positives_19: 29.0000 - true_negatives_19: 878.0000 - false_positives_18: 116.0000 - false_negatives_18: 153.0000 - val_loss: 1.4418 - val_accuracy: 0.7007 - val_true_positives_19: 2.0000 - val_true_negatives_19: 101.0000 - val_false_positives_18: 19.0000 - val_false_negatives_18: 25.0000
# Epoch 96/100
# 1/1 [==============================] - 0s 53ms/step - loss: 1.3473 - accuracy: 0.7704 - true_positives_19: 32.0000 - true_negatives_19: 874.0000 - false_positives_18: 120.0000 - false_negatives_18: 150.0000 - val_loss: 1.3733 - val_accuracy: 0.7007 - val_true_positives_19: 2.0000 - val_true_negatives_19: 101.0000 - val_false_positives_18: 19.0000 - val_false_negatives_18: 25.0000
# Epoch 97/100
# 1/1 [==============================] - 0s 61ms/step - loss: 1.2770 - accuracy: 0.7636 - true_positives_19: 32.0000 - true_negatives_19: 866.0000 - false_positives_18: 128.0000 - false_negatives_18: 150.0000 - val_loss: 1.3772 - val_accuracy: 0.7007 - val_true_positives_19: 3.0000 - val_true_negatives_19: 100.0000 - val_false_positives_18: 20.0000 - val_false_negatives_18: 24.0000
# Epoch 98/100
# 1/1 [==============================] - 0s 54ms/step - loss: 1.2071 - accuracy: 0.7534 - true_positives_19: 35.0000 - true_negatives_19: 851.0000 - false_positives_18: 143.0000 - false_negatives_18: 147.0000 - val_loss: 1.3127 - val_accuracy: 0.7007 - val_true_positives_19: 4.0000 - val_true_negatives_19: 99.0000 - val_false_positives_18: 21.0000 - val_false_negatives_18: 23.0000
# Epoch 99/100
# 1/1 [==============================] - 0s 53ms/step - loss: 1.1789 - accuracy: 0.7491 - true_positives_19: 40.0000 - true_negatives_19: 841.0000 - false_positives_18: 153.0000 - false_negatives_18: 142.0000 - val_loss: 1.3163 - val_accuracy: 0.7007 - val_true_positives_19: 4.0000 - val_true_negatives_19: 99.0000 - val_false_positives_18: 21.0000 - val_false_negatives_18: 23.0000
# Epoch 100/100
# 1/1 [==============================] - 0s 52ms/step - loss: 1.1473 - accuracy: 0.7432 - true_positives_19: 41.0000 - true_negatives_19: 833.0000 - false_positives_18: 161.0000 - false_negatives_18: 141.0000 - val_loss: 1.2337 - val_accuracy: 0.6871 - val_true_positives_19: 4.0000 - val_true_negatives_19: 97.0000 - val_false_positives_18: 23.0000 - val_false_negatives_18: 23.0000

# %%
loss, accuracy, tp, tn, fp, fn = model.evaluate(test_ds)
print("Accuracy", accuracy)

f1 = 2*tp/(2*tp + fp + fn)
print("F1 score", f1)
# Out:
# 1/1 [==============================] - 0s 27ms/step - loss: 1.9015 - accuracy: 0.6667 - true_positives_19: 2.0000 - true_negatives_19: 96.0000 - false_positives_18: 23.0000 - false_negatives_18: 26.0000
# Accuracy 0.6666666865348816
# F1 score 0.07547169811320754

# %%
model.save('job_satisfaction_classifier')
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) DistanceFromHome, MonthlyIncome, Age, JobSatisfaction, EnvironmentSatisfaction, JobInvolvement, PerformanceRating, RelationshipSatisfaction, WorkLifeBalance with unsupported characters which will be renamed to distancefromhome, monthlyincome, age, jobsatisfaction, environmentsatisfaction, jobinvolvement, performancerating, relationshipsatisfaction, worklifebalance in the SavedModel.
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: job_satisfaction_classifier\assets
# INFO:tensorflow:Assets written to: job_satisfaction_classifier\assets
